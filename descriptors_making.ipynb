# %%
import numpy as np
import functions as f

# %%
# Exemple avec HOG
f.make_descriptor_as_files("dataset_voitures/dataset", f.generateHOG, "HOG")

# Exemple avec LBP
f.make_descriptor_as_files("dataset_voitures/dataset", f.generateLBP, "LBP")

# Exemple avec GLCM
f.make_descriptor_as_files("dataset_voitures/dataset", f.generateGLCM, "GLCM")
# Out:
# HOG feature extraction finished in 0.02465200424194336 seconds !!!!
# HOG feature extraction finished in 0.003287792205810547 seconds !!!!
# HOG feature extraction finished in 0.00608515739440918 seconds !!!!
# HOG feature extraction finished in 0.0031232833862304688 seconds !!!!
# HOG feature extraction finished in 0.0037229061126708984 seconds !!!!
# HOG feature extraction finished in 0.0031490325927734375 seconds !!!!
# HOG feature extraction finished in 0.0030541419982910156 seconds !!!!
# HOG feature extraction finished in 0.004210472106933594 seconds !!!!
# HOG feature extraction finished in 0.0060994625091552734 seconds !!!!
# HOG feature extraction finished in 0.003657102584838867 seconds !!!!
# HOG feature extraction finished in 0.004399538040161133 seconds !!!!
# HOG feature extraction finished in 0.0032384395599365234 seconds !!!!
# HOG feature extraction finished in 0.003313302993774414 seconds !!!!
# HOG feature extraction finished in 0.00333404541015625 seconds !!!!
# ...

# %%
f.make_descriptor_as_files("dataset_voitures/dataset", f.generateHistogramme_Color,"Hist_Col")
f.make_descriptor_as_files("dataset_voitures/dataset", f.generateHistogramme_HSV,"HSV")
f.make_descriptor_as_files("dataset_voitures/dataset", f.generateORB,"ORB")
f.make_descriptor_as_files("dataset_voitures/dataset", f.generateSIFT,"SIFT")
# Out:
# indexation Hist Couleur finished in 0.007210731506347656 seconds !!!!
# indexation Hist Couleur finished in 0.0006206035614013672 seconds !!!!
# indexation Hist Couleur finished in 0.0007877349853515625 seconds !!!!
# indexation Hist Couleur finished in 0.0009109973907470703 seconds !!!!
# indexation Hist Couleur finished in 0.0006635189056396484 seconds !!!!
# indexation Hist Couleur finished in 0.000972747802734375 seconds !!!!
# indexation Hist Couleur finished in 0.0006632804870605469 seconds !!!!
# indexation Hist Couleur finished in 0.0006639957427978516 seconds !!!!
# indexation Hist Couleur finished in 0.0011191368103027344 seconds !!!!
# indexation Hist Couleur finished in 0.0010981559753417969 seconds !!!!
# indexation Hist Couleur finished in 0.0007975101470947266 seconds !!!!
# indexation Hist Couleur finished in 0.0006804466247558594 seconds !!!!
# indexation Hist Couleur finished in 0.0012428760528564453 seconds !!!!
# ...

# %%
f.make_descriptor_as_files("dataset_voitures/dataset", f.generateResNet50, "ResNet50")
# Out:
# ResNet50 feature extraction finished in 1.6807701587677002 seconds !!!!
# ResNet50 feature extraction finished in 0.11510396003723145 seconds !!!!
# ResNet50 feature extraction finished in 0.1325538158416748 seconds !!!!
# ResNet50 feature extraction finished in 0.12285327911376953 seconds !!!!
# ResNet50 feature extraction finished in 0.13196873664855957 seconds !!!!
# ResNet50 feature extraction finished in 0.12754201889038086 seconds !!!!
# ResNet50 feature extraction finished in 0.1233510971069336 seconds !!!!
# ResNet50 feature extraction finished in 0.12858080863952637 seconds !!!!
# ResNet50 feature extraction finished in 0.12234354019165039 seconds !!!!
# ResNet50 feature extraction finished in 0.1334071159362793 seconds !!!!
# ResNet50 feature extraction finished in 0.13130998611450195 seconds !!!!
# ResNet50 feature extraction finished in 0.11539340019226074 seconds !!!!
# ResNet50 feature extraction finished in 0.13045001029968262 seconds !!!!
# ...
